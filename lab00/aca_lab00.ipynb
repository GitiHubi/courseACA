# %% [markdown]
# <img align="right" style="max-width: 200px; height: auto" src="01_images/hsg_logo.png">
#
# ### Lab 00 - "Jupyter Notebook Analyseumgebung"
#
# ACA Lehrgang "Internal Audit Knowledge Elements", Universität St. Gallen, 15. Januar 2020

# %% [markdown]
# Die Laborumgebung des Kurses **"Internal Audit Knowledge Elements"** an der Universität St. Gallen basiert auf Jupyter Notebooks (https://jupyter.org), die es erlauben, eine Vielzahl von statistischen Auswertungen und Datenanalysen durchzuführen.

# %% [markdown]
# <img align="center" style="max-width: 700px" src="01_images/banner.png">

# %% [markdown]
# Mit diesem initialen Notebook möchten wir sicherstellen, dass Jupyter Notebook und Python richtig eingerichtet sind und Sie den ersten Satz der notwendigen Python Programmierbibliotheken installiert haben. Darüber hinaus möchten wir auf die grundlegenden Konzepte und die Anwendung solcher Notizbücher eingehen. Dies wird im folgenden Anhand einiger einführender Beispiele demonstriert.
#
# Zögern Sie bitte nicht Fragen entweder unmittelbar während der Durchführung des Labs zu stellen oder uns im Nachgang eine E-Mail an marco.schreyer@unisg.ch zu senden. **Happy coding!**

# %% [markdown]
# ### Test 1: Ausführen eines Befehls in Python

# %% [markdown]
# Lassen Sie uns beispielhaft eine Addition in der Python Programmiersprache ausführen um zu prüfen ob Python vollständig in der Lab Umgebung installiert wurde und nachfolgend zur Verfügung steht:

# %%
# ausführen einer einfachen Addition
1 + 1
# Out:
# 2

# %% [markdown]
# ### Test 2: Import von Python Programmierbibliotheken

# %% [markdown]
# Lassen Sie uns nun beispielhaft ein paar Python Programmierbibliotheken importieren um zu prüfen ob diese vollständig in der Lab Umgebung installiert wurden und nachfolgend zur Verfügung stehen:

# %%
# importieren ausgewählter Python Programmierbibliotheken
import numpy
import scipy
import matplotlib
import seaborn
import sklearn
import pandas

# %% [markdown]
# Wenn die obigen Code-Zellen ohne einen Fehler ausgeführt werden, sollten Sie für die kommenden Labs bereit sein :)

# %% [markdown]
# ### Lernziele des Labs:

# %% [markdown]
# Das vorliegende Lab sollte Ihnen ermöglichen:
#
# > 1. Den Aufbau, die Struktur sowie die Funktionsweise von **Jupyter**-Notebooks zu verstehen.
# > 2. Python Programmierbibliotheken wie **Numpy** zu importieren und deren Funktionalität anzuwenden.
# > 3. Daten unter Verwendung der **Matplotlib**-Bibliothek zu visualisieren.

# %% [markdown]
# ### 1. Programmieren in Jupyter Notebooks

# %% [markdown]
# #### 1.1. Code Zellen und Text Zellen

# %% [markdown]
# Jupyter Notebooks bestehen im Wesentlichen aus zwei Arten von Zellen: (1) Code-Zellen und (2) Text-Zellen. Code-Zellen dienen der Ausführung von Code bzw. Befehlen in der Programmiersprache Python. Text-Zellen dienen der Dokumentation bzw. der Beschreibung der ausgeführten Befehle bzw. durchgeführten Analysen. Jede Zelle eines Notebooks kann hierbei wahlweise eine Code-Zelle oder eine Text-Zelle darstellen. Um zwischen beiden Zellarten zu wählen, wählen Sie aus dem Dropdown-Menü oben links die entsprechende Zellart aus.

# %% [markdown]
# Hello World!

# %%
1 + 5
# Out:
# 6

# %% [markdown]
# #### 1.2. Ausführen eines Befehls

# %% [markdown]
# Eine Codezelle wird ausgewertet, wenn Sie **'Run'** drücken oder wenn Sie die Tastenkombination, Shift-Eingabe, drücken. Bei der Auswertung einer Zelle wird jede Codezeile der Reihe nach ausgewertet und das Ergebnis der letzten Zeile unter der Zelle ausgedruckt.

# %%
40 + 2
# Out:
# 42

# %% [markdown]
# Manchmal gibt es kein Ergebnis zu drucken, wie bei der folgenden Zuordnung:

# %%
x = 2

# %%
x
# Out:
# 2

# %% [markdown]
# Bitte denken Sie daran, dass nur das Ergebnis der letzten Zeile gedruckt wird:

# %%
2 + 2
3 + 3
# Out:
# 6

# %% [markdown]
# Sie können jedoch mit der Druckanweisung `print` beliebige Zeilen drucken:

# %%
print(2 + 2)
3 + 3
# Out:
# 4
# 6

# %% [markdown]
# #### 1.3. Laufzeit eines Befehls

# %% [markdown]
# Während eine Zelle läuft, wird links von der jeweiligen Zelle ein **[*]** angezeigt. Wenn eine Zelle noch nicht ausgeführt wurde, wird ein **[ ]** angezeigt. Wenn sie ausgeführt wurde, wird eine Zahl angezeigt, die die Reihenfolge angibt, in der sie während der Ausführung des Notebooks ausgeführt wurde **[5]**. Probieren Sie diese Zelle an und notieren Sie, was passiert:

# %%
# take some time to run something
c = 0
for i in range(10000000):
    c = c + i
c
# Out:
# 49999995000000

# %% [markdown]
# ### 2. Import und Anwendung Python Programmierbibliotheken

# %% [markdown]
# Die überwiegende Mehrheit der Zeit werden wir Funktionen aus vorgefertigten Bibliotheken verwenden, wie z.B:

# %%
import sys

# %% [markdown]
# Die `Sys` Bibliothek bietet beispielsweise die Möglichkeit die aktuell innerhalb des Notebook verwendete Python Version zu ermitteln. Dies ist anhand des nachfolgenden Befehls möglich:

# %%
sys.version
# Out:
# '3.7.4 (default, Jul  9 2019, 18:15:00) \n[Clang 10.0.0 (clang-1000.11.45.5)]'

# %% [markdown]
# Aus Sicherheitsgründen ist es oftmals nicht möglich jede verfügbare Bibliothek in ein Jupyter Notebook zu importieren. Für die meisten der gängigen wissenschaftlichen Bibliotheken ist dies jedoch problemlos möglich. Nachfolgend importieren wir die Bibliotheken `Numpy` (https://www.numpy.org) und `Pandas` (https://pandas.pydata.org), zwei der gebräuchlichsten und nützlichsten Bibliotheken im Kontext von "Data Science" bzw. "Data Analytics". Wir empfehlen, solche Import-Anweisungen für jedes neue Notebook, das Sie erstellen, zu kopieren:

# %%
## import der Numpy and Pandas Programmierbibliothek
import numpy
import pandas

# %% [markdown]
# Benutzen wir nun beispielsweise die importiete `Numpy` Bibliothek, um den Mittelwert einer beliebigen Reihe von Zahlen zu berechnen:

# %%
numpy.mean([1, 2, 3, 4])
# Out:
# 2.5

# %% [markdown]
# Die `as` Anweisung in Python erlaubt die Zuweisung eines sogenannten Aliases für eine bestimmte Programmierbibliothek. Nachfolgend werden die beiden Bibliotheken `Numpy` und `Pandas` importiert und diesen jeweils der Alias `np` bzw. `pd` zugeordnet. Dies ist ein sehr gebräuchliches "Aliasing" der beiden Bibliotheken. Ein solcher Alias erlaubt es im Nachgang des Imports unter Verwendung des Alias auf die einzelnen Funktionen einer Programmierbibliothek zuzugreifen. Dies ist im Besonderen dann hilfreich, wenn eine Bibliothek im Rahmen einer Analyse häufig aufgerufen wird:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Benutzen wir nun den vergebenen Alias `np` der `Numpy` Bibliothek, um den Mittelwert einer beliebigen Reihe von Zahlen zu berechnen:

# %%
np.mean([1, 2, 3, 4])
# Out:
# 2.5

# %% [markdown]
# ### 3. Visualiserung von Daten in Jupyter Notebooks

# %% [markdown]
# #### 3.1. Erzeugung von Zufallszahlen

# %% [markdown]
# Erzeugung von 100 Zufallszahlen von einer Normalverteilung mit Mittelwert 0.0 und Standardabweichung 1.0 unter Verwendung der `Numpy` Programmierbibliothek:

# %%
x = np.random.normal(0, 1, 100)

# %% [markdown]
# Ausgabe der erzeugten Zufallsvariablen:

# %%
x
# Out:
# array([ 0.77777993,  1.42838861,  0.23820595,  0.93441262,  0.99016183,
#         0.80244256,  0.17483415,  0.80176403,  0.61439501,  0.85719647,
#        -1.47713882,  0.66450887,  0.70120846,  1.80250072,  0.19504294,
#        -0.60505246, -0.38043682,  2.67420018, -0.50317206,  1.49585507,
#        -0.54020302, -1.98272013, -0.05746756,  0.25718612,  1.51875259,
#        -0.6977221 , -1.33568556, -0.01357292,  0.25506116, -0.43714356,
#        -0.15130236,  0.02206903,  0.37801647, -0.52773825,  1.14266991,
#        -0.2322628 , -0.1695448 , -0.00613751,  1.98501118,  0.69024711,
#        -0.06117709, -1.66409779, -0.38806917, -1.18546442,  0.86741454,
#         0.75307733,  0.88216334, -0.80747993,  0.14341943,  0.06430702,
#         1.0190751 , -1.793392  ,  0.40821133, -0.17837759,  0.46829277,
#         0.39780697, -0.12469815,  0.80839671,  1.17088592,  0.25665214,
#         0.68894237,  1.19288665, -0.71260005, -1.07578589,  0.73122431,
# ...

# %% [markdown]
# #### 3.2. Visualisierung der Zufallszahlen

# %% [markdown]
# Bei Python's `Matplotlib` Bibliothek (https://matplotlib.org) handelt es sich um eine flexible Bibliothek für die Visualiserung unterschiedlichster Datenbestände. `Matplotlib` bietet hierbei eine Menge praktischer, eingebauter Voreinstellungen, die Ihnen enorm helfen können eigen Daten zu Visualisieren. Hierzu müssen Sie zunächst die Bibliothek in Ihre Jupyter Notebook Analyseumgebung importieren. Anschließend konnen Sie beliebige Daten, beispielsweise mit Hilfe der `plot()` Funktion, visualisieren.

# %% [markdown]
# Import der `Matplotlib` Programmierbibliothek:

# %%
# importing the matplotlib plotting library
import matplotlib.pyplot as plt

# %% [markdown]
# Bitte beachten Sie, dass wir das `Pyplot` Modul der `Matplotlib` Bibliothek unter dem Alias `plt` importiert haben.

# %% [markdown]
# Wir können nun die von `Matplotlib` bereitgestellte Funktionalität zur Visualiserung von Daten wie folgt nutzen:

# %%
plt.plot(x)

# %% [markdown]
# Lassen Sie uns nun ein paar Eigenschaften der Visualisierung verändern sowie Achsenbeschriftungen hinzufügen:

# %%
# visualisiere Reihe an Zufallszahlen
plt.plot(x, linewidth=3, linestyle='--', color='green')

# hinzufügen der Achsenbeschriftungen
plt.xlabel('sample', weight='normal', fontsize=8)
plt.ylabel('value', weight='normal', fontsize=8)
# Out:
# Text(0, 0.5, 'value')

# %% [markdown]
# #### 3.3. Entfernen der Ausgabe des letzten Befehls

# %% [markdown]
# Sie haben vielleicht die Ausgabe der nachfolgenden überflüssigen Zeile `Text(0, 0.5, 'Wert')` vor der erstellten Visualisierung bemerkt. Sofern Sie diese Ausgabe unterbinden möchten, beenden Sie einfach den letzten Befehl innerhalb der Code-Zelle mit einem Semikolon `;`:

# %%
# visualisiere Reihe an Zufallszahlen
plt.plot(x, linewidth=3, linestyle='--', color='green')

# hinzufügen der Achsenbeschriftungen
plt.xlabel('sample', weight='normal', fontsize=8)
plt.ylabel('value', weight='normal', fontsize=8);

# %% [markdown]
# #### 3.4. Hinzufügen eines Titels und einer Legende

# %% [markdown]
# Kein selbstbewusster Datenanalyst erstellt ein Diagramm ohne beschriftete Achsen, Titel und Legende. Im Folgenden finden Sie eine paar Befehle die Ihnen hierbei nützlich sein können. Wir erzeugen hierbei zunächst zwei mal je 100 Zufallszahlen von einer Normalverteilung mit Mittelwert 0.0 und Standardabweichung 1.0:

# %%
x1 = np.random.normal(0, 1, 100)
x2 = np.random.normal(0, 1, 100)

# %% [markdown]
# Visualiserung beider Reihen an Zufallszahlen in einem Diagramm samt Titel und Legende:

# %%
# visualisiere beide Reihen an Zufallszahlen
plt.plot(x1)
plt.plot(x2)

# hinzufügen der Achsenbeschriftungen
plt.xlabel('Time')
plt.ylabel('Returns')

# hinzufügen der Legende
plt.legend(['X1', 'X2'])

# hinzufügen des Titels
plt.title('Sample Returns X1 and X2');

# %% [markdown]
# ### Zusammenfassung

# %% [markdown]
# In diesem ersten Lab wurde eine schrittweise Einführung in einige grundlegende Konzepte der Datenanalyse mit Jupyter-Notebooks vorgestellt. Die Vorgehensweise sowie der Code die in diesem Labor präsentiert werden, können Ihnen als Ausgangspunkt für komplexere und maßgeschneiderte Analysen dienen.
